# %%
import seaborn as sns
import matplotlib.pyplot as plt

phool = sns.load_dataset("iris")
#draw a line plot
sns.lineplot(x="sepal_length",y = "sepal_width",data=phool)
plt.title("Phoolo ka plots")
plt.show()

# %%
phool = sns.load_dataset("iris")

#draw a line plot
sns.lineplot(x="sepal_length",y = "sepal_width",data=phool)
plt.title("Phoolo ka plots")
plt.xlim(2)
plt.ylim(1)
plt.show()

# %% [markdown]
# ## `Set styles`
# - darkgrid
# - whitegrid
# - dark
# - white
# - ticks

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#sns.set_style(style=None,rc=None)
phool = sns.load_dataset("iris")
#draw a line plot
sns.lineplot(x="sepal_length",y = "sepal_width",data=phool)
plt.title("Phoolo ka plots")
sns.set_style('whitegrid')# fot this u need to run 2 times
plt.show()

# %% [markdown]
# ## size of figure

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#set null
#sns.set_style(style=None,rc = None)
phool = sns.load_dataset("iris")
#chnge figure
plt.figure(figsize=(12,5))
#draw a line plot
sns.lineplot(x="sepal_length",y = "sepal_width",data=phool)
plt.title("Phoolo ka plots")
sns.set_style("darkgrid")
plt.show()
